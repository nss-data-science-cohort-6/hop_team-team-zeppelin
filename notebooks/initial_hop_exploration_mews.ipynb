# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import sqlite3
from tqdm.notebook import tqdm
import numpy as np

# %% [markdown]
# ## NPI/NPPES Data

# %%
# list of columns needed for our project
select_cols = ['NPI',
               'Entity Type Code',
               'Provider Organization Name (Legal Business Name)',
               'Provider Last Name (Legal Name)',
               'Provider First Name',
               'Provider Middle Name',
               'Provider Name Prefix Text',
               'Provider Name Suffix Text',
               'Provider Credential Text',
               'Provider First Line Business Mailing Address',
               'Provider Second Line Business Mailing Address',
               'Provider Business Mailing Address City Name',
               'Provider Business Mailing Address State Name',
               'Provider Business Mailing Address Postal Code',
               'Healthcare Provider Taxonomy Code_1', 'Healthcare Provider Primary Taxonomy Switch_1',
               'Healthcare Provider Taxonomy Code_2', 'Healthcare Provider Primary Taxonomy Switch_2',
               'Healthcare Provider Taxonomy Code_3', 'Healthcare Provider Primary Taxonomy Switch_3',
               'Healthcare Provider Taxonomy Code_4', 'Healthcare Provider Primary Taxonomy Switch_4',
               'Healthcare Provider Taxonomy Code_5', 'Healthcare Provider Primary Taxonomy Switch_5',
               'Healthcare Provider Taxonomy Code_6', 'Healthcare Provider Primary Taxonomy Switch_6',
               'Healthcare Provider Taxonomy Code_7', 'Healthcare Provider Primary Taxonomy Switch_7',
               'Healthcare Provider Taxonomy Code_8', 'Healthcare Provider Primary Taxonomy Switch_8',
               'Healthcare Provider Taxonomy Code_9', 'Healthcare Provider Primary Taxonomy Switch_9',
               'Healthcare Provider Taxonomy Code_10', 'Healthcare Provider Primary Taxonomy Switch_10',
               'Healthcare Provider Taxonomy Code_11', 'Healthcare Provider Primary Taxonomy Switch_11',
               'Healthcare Provider Taxonomy Code_12', 'Healthcare Provider Primary Taxonomy Switch_12',
               'Healthcare Provider Taxonomy Code_13', 'Healthcare Provider Primary Taxonomy Switch_13',
               'Healthcare Provider Taxonomy Code_14', 'Healthcare Provider Primary Taxonomy Switch_14',
               'Healthcare Provider Taxonomy Code_15', 'Healthcare Provider Primary Taxonomy Switch_15']

# %%
# Pull a sample of the data to explore
npi_sample = pd.read_csv('../data/npidata_pfile_20050523-20230212.csv',
                         usecols = select_cols,
                         skiprows = range(1, 100600),
                         nrows = 100000)
# Out:
# C:\Users\mews2\AppData\Local\Temp\ipykernel_20152\196031574.py:2: DtypeWarning: Columns (24,63,66,67,70,71,74,75,78,79,82,83,86,87,90,91,94,95,98,99,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   npi_sample = pd.read_csv('../data/npidata_pfile_20050523-20230212.csv',

# %%
npi_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 44 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   NPI                                               100000 non-null  int64
#  1   Entity Type Code                                  100000 non-null  int64
#  2   Provider Organization Name (Legal Business Name)  0 non-null       float64
#  3   Provider Last Name (Legal Name)                   99996 non-null   object
#  4   Provider First Name                               100000 non-null  object
#  5   Provider Middle Name                              75143 non-null   object
#  6   Provider Name Prefix Text                         55211 non-null   object
#  7   Provider Name Suffix Text                         3020 non-null    object
#  8   Provider Credential Text                          94403 non-null   object
#  9   Provider First Line Business Mailing Address      100000 non-null  object
#  10  Provider Second Line Business Mailing Address     29959 non-null   object
#  11  Provider Business Mailing Address City Name       100000 non-null  object
#  12  Provider Business Mailing Address State Name      100000 non-null  object
#  13  Provider Business Mailing Address Postal Code     100000 non-null  object
#  14  Healthcare Provider Taxonomy Code_1               100000 non-null  object
#  15  Healthcare Provider Primary Taxonomy Switch_1     100000 non-null  object
#  16  Healthcare Provider Taxonomy Code_2               6097 non-null    object
#  17  Healthcare Provider Primary Taxonomy Switch_2     6097 non-null    object
#  18  Healthcare Provider Taxonomy Code_3               1180 non-null    object
#  19  Healthcare Provider Primary Taxonomy Switch_3     1180 non-null    object
#  20  Healthcare Provider Taxonomy Code_4               400 non-null     object
#  21  Healthcare Provider Primary Taxonomy Switch_4     400 non-null     object
#  22  Healthcare Provider Taxonomy Code_5               169 non-null     object
#  23  Healthcare Provider Primary Taxonomy Switch_5     169 non-null     object
#  24  Healthcare Provider Taxonomy Code_6               115 non-null     object
#  25  Healthcare Provider Primary Taxonomy Switch_6     115 non-null     object
#  26  Healthcare Provider Taxonomy Code_7               70 non-null      object
#  27  Healthcare Provider Primary Taxonomy Switch_7     70 non-null      object
#  28  Healthcare Provider Taxonomy Code_8               45 non-null      object
#  29  Healthcare Provider Primary Taxonomy Switch_8     45 non-null      object
#  30  Healthcare Provider Taxonomy Code_9               37 non-null      object
#  31  Healthcare Provider Primary Taxonomy Switch_9     37 non-null      object
#  32  Healthcare Provider Taxonomy Code_10              26 non-null      object
#  33  Healthcare Provider Primary Taxonomy Switch_10    26 non-null      object
#  34  Healthcare Provider Taxonomy Code_11              20 non-null      object
#  35  Healthcare Provider Primary Taxonomy Switch_11    20 non-null      object
#  36  Healthcare Provider Taxonomy Code_12              15 non-null      object
#  37  Healthcare Provider Primary Taxonomy Switch_12    15 non-null      object
#  38  Healthcare Provider Taxonomy Code_13              6 non-null       object
#  39  Healthcare Provider Primary Taxonomy Switch_13    6 non-null       object
#  40  Healthcare Provider Taxonomy Code_14              2 non-null       object
#  41  Healthcare Provider Primary Taxonomy Switch_14    2 non-null       object
#  42  Healthcare Provider Taxonomy Code_15              0 non-null       float64
#  43  Healthcare Provider Primary Taxonomy Switch_15    0 non-null       float64
# dtypes: float64(3), int64(2), object(39)
# memory usage: 33.6+ MB

# %%
# How many providers don't indicate a primary taxonomy code, designated by a value of 'X'?
npi_sample['Healthcare Provider Primary Taxonomy Switch_1'].value_counts()
# Based on looking at a few chunks, it appears to be around 4%
# Out:
# Y    95584
# X     3908
# N      508
# Name: Healthcare Provider Primary Taxonomy Switch_1, dtype: int64

# %%
# For providers that have indicated a primary taxonomy code, pull that code into the primary_taxonomy column
npi_sample['taxonomy_code'] = np.nan

for n in range(1, 16):
    x = str(n)
    npi_sample.loc[npi_sample[f'Healthcare Provider Primary Taxonomy Switch_{x}'] == 'Y', 
                   'taxonomy_code'] = npi_sample[f'Healthcare Provider Taxonomy Code_{x}']

# %%
# For providers that do not indicate a primary taxonomy code, pull the code from the first taxonomy column
npi_sample.loc[npi_sample['taxonomy_code'].isna(), 'taxonomy_code'] = npi_sample['Healthcare Provider Taxonomy Code_1']

# %%
npi_sample = npi_sample.drop(columns = ['Healthcare Provider Taxonomy Code_1', 'Healthcare Provider Primary Taxonomy Switch_1',
                                  'Healthcare Provider Taxonomy Code_2', 'Healthcare Provider Primary Taxonomy Switch_2',
                                  'Healthcare Provider Taxonomy Code_3', 'Healthcare Provider Primary Taxonomy Switch_3',
                                  'Healthcare Provider Taxonomy Code_4', 'Healthcare Provider Primary Taxonomy Switch_4',
                                  'Healthcare Provider Taxonomy Code_5', 'Healthcare Provider Primary Taxonomy Switch_5',
                                  'Healthcare Provider Taxonomy Code_6', 'Healthcare Provider Primary Taxonomy Switch_6',
                                  'Healthcare Provider Taxonomy Code_7', 'Healthcare Provider Primary Taxonomy Switch_7',
                                  'Healthcare Provider Taxonomy Code_8', 'Healthcare Provider Primary Taxonomy Switch_8',
                                  'Healthcare Provider Taxonomy Code_9', 'Healthcare Provider Primary Taxonomy Switch_9',
                                  'Healthcare Provider Taxonomy Code_10', 'Healthcare Provider Primary Taxonomy Switch_10',
                                  'Healthcare Provider Taxonomy Code_11', 'Healthcare Provider Primary Taxonomy Switch_11',
                                  'Healthcare Provider Taxonomy Code_12', 'Healthcare Provider Primary Taxonomy Switch_12',
                                  'Healthcare Provider Taxonomy Code_13', 'Healthcare Provider Primary Taxonomy Switch_13',
                                  'Healthcare Provider Taxonomy Code_14', 'Healthcare Provider Primary Taxonomy Switch_14',
                                  'Healthcare Provider Taxonomy Code_15', 'Healthcare Provider Primary Taxonomy Switch_15'])

# %%
npi_sample
# Out:
#               NPI  Entity Type Code  \
# 0      1013955939                 1
# 1      1659319572                 1
# 2      1093753915                 1
# 3      1811935737                 1
# 4      1720026644                 1
# ...           ...               ...
# 99995  1669580163                 1
# 99996  1487762985                 1
# 99997  1396853792                 1
# 99998  1023126422                 1
# 99999  1750499158                 1
#
#        Provider Organization Name (Legal Business Name)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 99995                                               NaN
# 99996                                               NaN
# 99997                                               NaN
# 99998                                               NaN
# 99999                                               NaN
#
#       Provider Last Name (Legal Name) Provider First Name  \
# 0                      MCCLURE-MARING               LYDIA
# 1                               ESTES                JANE
# 2                             BUCHELE              BONNIE
# 3                             TENORIO            ROSALINE
# 4                               PRYOR               TERRI
# ...                               ...                 ...
# 99995                           EVANS              ARTHUR
# 99996                         STIGALL               LARRY
# 99997                            KURZ              EDWARD
# 99998                          MURATA                FARA
# 99999                           NITTI               DAVID
#
#       Provider Middle Name Provider Name Prefix Text  \
# 0                       JO                       MS.
# 1                      NaN                       NaN
# 2                       B.                       DR.
# 3                        R                       NaN
# 4                        L                       NaN
# ...                    ...                       ...
# 99995                    F                       DR.
# 99996              EVERETT                       MR.
# 99997               GEORGE                       DR.
# 99998                DIANE                       NaN
# 99999                 JOHN                       DR.
#
#       Provider Name Suffix Text Provider Credential Text  \
# 0                           NaN                     CRNP
# 1                           NaN                     LCSW
# 2                           NaN                    PH.D.
# 3                           NaN                     CNNP
# 4                           NaN                       PA
# ...                         ...                      ...
# 99995                       NaN                      DDS
# 99996                       NaN                      DDS
# 99997                       NaN                      DDS
# 99998                       NaN                     LCSW
# 99999                       NaN                       MD
#
#       Provider First Line Business Mailing Address  \
# 0                                     220 LOWRY RD
# 1                                      PO BOX 1589
# 2                                   411 NICHOLS RD
# 3                                5901 HARPER DR NE
# 4                            16706 NATIONAL HWY SW
# ...                                            ...
# 99995                                   PO BOX 186
# 99996                               240 DOCTORS DR
# 99997                            330 N CHESTNUT ST
# 99998                     5738 OLDE WADSWORTH BLVD
# 99999                         179 LAFAYETTE AVENUE
#
#       Provider Second Line Business Mailing Address  \
# 0                                               NaN
# 1                                               NaN
# 2                                         SUITE 194
# 3                               PROVIDER ENROLLMENT
# 4                                               NaN
# ...                                             ...
# 99995                                           NaN
# 99996                                           NaN
# 99997                                           NaN
# 99998                                           NaN
# 99999                                           NaN
#
#       Provider Business Mailing Address City Name  \
# 0                                            ERIE
# 1                                          BENTON
# 2                                     KANSAS CITY
# 3                                     ALBUQUERQUE
# 4                                       FROSTBURG
# ...                                           ...
# 99995                                    GRANETTE
# 99996                                       BOONE
# 99997                                     RAVENNA
# 99998                                      ARVADA
# 99999                                   HAWTHORNE
#
#       Provider Business Mailing Address State Name  \
# 0                                               PA
# 1                                               AR
# 2                                               MO
# 3                                               NM
# 4                                               MD
# ...                                            ...
# 99995                                           AR
# 99996                                           NC
# 99997                                           OH
# 99998                                           CO
# 99999                                           NJ
#
#       Provider Business Mailing Address Postal Code taxonomy_code
# 0                                         165111327    363L00000X
# 1                                         720181589    1041C0700X
# 2                                         641122000    103TC0700X
# 3                                         871093587    363LN0000X
# 4                                         215323304    363AM0700X
# ...                                             ...           ...
# 99995                                         72736    1223G0001X
# 99996                                         28607    122300000X
# 99997                                     442662216    122300000X
# 99998                                     800022535    1041C0700X
# 99999                                      75062613    207R00000X
#
# [100000 rows x 15 columns]

# %%
zips = []
for x in npi_sample['Provider Business Mailing Address Postal Code']:
    if len(x.astype(str)) > 5:
        zips.append(x.zfill(9)[:5])
    elif len(x) > 0:
        zips.append(x.zfill(5))
    else: zips.append(np.nan)

zips
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 2>()
#       1 zips = []
#       2 for x in npi_sample['Provider Business Mailing Address Postal Code']:
# ----> 3     if len(x.astype(str)) > 5:
#       4         zips.append(x.zfill(9)[:5])
#       5     elif len(x) > 0:
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
npi_sample
# Out:
#               NPI  Entity Type Code  \
# 0      1013955939                 1
# 1      1659319572                 1
# 2      1093753915                 1
# 3      1811935737                 1
# 4      1720026644                 1
# ...           ...               ...
# 99995  1669580163                 1
# 99996  1487762985                 1
# 99997  1396853792                 1
# 99998  1023126422                 1
# 99999  1750499158                 1
#
#        Provider Organization Name (Legal Business Name)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 99995                                               NaN
# 99996                                               NaN
# 99997                                               NaN
# 99998                                               NaN
# 99999                                               NaN
#
#       Provider Last Name (Legal Name) Provider First Name  \
# 0                      MCCLURE-MARING               LYDIA
# 1                               ESTES                JANE
# 2                             BUCHELE              BONNIE
# 3                             TENORIO            ROSALINE
# 4                               PRYOR               TERRI
# ...                               ...                 ...
# 99995                           EVANS              ARTHUR
# 99996                         STIGALL               LARRY
# 99997                            KURZ              EDWARD
# 99998                          MURATA                FARA
# 99999                           NITTI               DAVID
#
#       Provider Middle Name Provider Name Prefix Text  \
# 0                       JO                       MS.
# 1                      NaN                       NaN
# 2                       B.                       DR.
# 3                        R                       NaN
# 4                        L                       NaN
# ...                    ...                       ...
# 99995                    F                       DR.
# 99996              EVERETT                       MR.
# 99997               GEORGE                       DR.
# 99998                DIANE                       NaN
# 99999                 JOHN                       DR.
#
#       Provider Name Suffix Text Provider Credential Text  \
# 0                           NaN                     CRNP
# 1                           NaN                     LCSW
# 2                           NaN                    PH.D.
# 3                           NaN                     CNNP
# 4                           NaN                       PA
# ...                         ...                      ...
# 99995                       NaN                      DDS
# 99996                       NaN                      DDS
# 99997                       NaN                      DDS
# 99998                       NaN                     LCSW
# 99999                       NaN                       MD
#
#       Provider First Line Business Mailing Address  \
# 0                                     220 LOWRY RD
# 1                                      PO BOX 1589
# 2                                   411 NICHOLS RD
# 3                                5901 HARPER DR NE
# 4                            16706 NATIONAL HWY SW
# ...                                            ...
# 99995                                   PO BOX 186
# 99996                               240 DOCTORS DR
# 99997                            330 N CHESTNUT ST
# 99998                     5738 OLDE WADSWORTH BLVD
# 99999                         179 LAFAYETTE AVENUE
#
#       Provider Second Line Business Mailing Address  \
# 0                                               NaN
# 1                                               NaN
# 2                                         SUITE 194
# 3                               PROVIDER ENROLLMENT
# 4                                               NaN
# ...                                             ...
# 99995                                           NaN
# 99996                                           NaN
# 99997                                           NaN
# 99998                                           NaN
# 99999                                           NaN
#
#       Provider Business Mailing Address City Name  \
# 0                                            ERIE
# 1                                          BENTON
# 2                                     KANSAS CITY
# 3                                     ALBUQUERQUE
# 4                                       FROSTBURG
# ...                                           ...
# 99995                                    GRANETTE
# 99996                                       BOONE
# 99997                                     RAVENNA
# 99998                                      ARVADA
# 99999                                   HAWTHORNE
#
#       Provider Business Mailing Address State Name  \
# 0                                               PA
# 1                                               AR
# 2                                               MO
# 3                                               NM
# 4                                               MD
# ...                                            ...
# 99995                                           AR
# 99996                                           NC
# 99997                                           OH
# 99998                                           CO
# 99999                                           NJ
#
#       Provider Business Mailing Address Postal Code taxonomy_code
# 0                                             16511    363L00000X
# 1                                             72018    1041C0700X
# 2                                             64112    103TC0700X
# 3                                             87109    363LN0000X
# 4                                             21532    363AM0700X
# ...                                             ...           ...
# 99995                                           NaN    1223G0001X
# 99996                                           NaN    122300000X
# 99997                                           NaN    122300000X
# 99998                                           NaN    1041C0700X
# 99999                                           NaN    207R00000X
#
# [100000 rows x 15 columns]

# %% [markdown]
# # Create the hop_team SQLite database
# db = sqlite3.connect('../data/hop_team.sqlite')
#
# # create the providers table from npi/nppes data and add it to the database
# for chunk in tqdm(pd.read_csv('../data/npidata_pfile_20050523-20230212.csv',
#                               usecols = select_cols,
#                               chunksize = 10000)):
#
#     # For providers that have indicated a primary taxonomy code, pull that code into the primary_taxonomy column
#     npi_sample['taxonomy_code'] = np.nan
#     for n in range(1, 16):
#         x = str(n)
#         npi_sample.loc[npi_sample[f'Healthcare Provider Primary Taxonomy Switch_{x}'] == 'Y',
#                        'taxonomy_code'] = npi_sample[f'Healthcare Provider Taxonomy Code_{x}']
#
#     # For providers that do not indicate a primary taxonomy code, pull the code from the first taxonomy column
#     npi_sample.loc[npi_sample['taxonomy_code'].isna(), 'taxonomy_code'] = npi_sample['Healthcare Provider Taxonomy Code_1']
#
#     # Drop the columns no longer needed
#     chunk = chunk.drop(columns = ['Healthcare Provider Taxonomy Code_1', 'Healthcare Provider Primary Taxonomy Switch_1',
#                                   'Healthcare Provider Taxonomy Code_2', 'Healthcare Provider Primary Taxonomy Switch_2',
#                                   'Healthcare Provider Taxonomy Code_3', 'Healthcare Provider Primary Taxonomy Switch_3',
#                                   'Healthcare Provider Taxonomy Code_4', 'Healthcare Provider Primary Taxonomy Switch_4',
#                                   'Healthcare Provider Taxonomy Code_5', 'Healthcare Provider Primary Taxonomy Switch_5',
#                                   'Healthcare Provider Taxonomy Code_6', 'Healthcare Provider Primary Taxonomy Switch_6',
#                                   'Healthcare Provider Taxonomy Code_7', 'Healthcare Provider Primary Taxonomy Switch_7',
#                                   'Healthcare Provider Taxonomy Code_8', 'Healthcare Provider Primary Taxonomy Switch_8',
#                                   'Healthcare Provider Taxonomy Code_9', 'Healthcare Provider Primary Taxonomy Switch_9',
#                                   'Healthcare Provider Taxonomy Code_10', 'Healthcare Provider Primary Taxonomy Switch_10',
#                                   'Healthcare Provider Taxonomy Code_11', 'Healthcare Provider Primary Taxonomy Switch_11',
#                                   'Healthcare Provider Taxonomy Code_12', 'Healthcare Provider Primary Taxonomy Switch_12',
#                                   'Healthcare Provider Taxonomy Code_13', 'Healthcare Provider Primary Taxonomy Switch_13',
#                                   'Healthcare Provider Taxonomy Code_14', 'Healthcare Provider Primary Taxonomy Switch_14',
#                                   'Healthcare Provider Taxonomy Code_15', 'Healthcare Provider Primary Taxonomy Switch_15'])
#
#     chunk.columns = [x.lower()
#                      .replace('provider ', '')
#                      .replace('business ', '')
#                      .replace(' text', '')
#                      .replace(' (legal name)', '')
#                      .replace(' ', '_') for x in chunk.columns]                  # Clean up the column names
#
#     chunk.to_sql('provider', db, if_exists = 'append', index = False)            # append to provider table

# %% [markdown]
# ## Taxonomy Details

# %%
tax_deets = pd.read_csv('../data/nucc_taxonomy_230.csv')

# %%
tax_deets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 873 entries, 0 to 872
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Code            873 non-null    object
#  1   Grouping        873 non-null    object
#  2   Classification  873 non-null    object
#  3   Specialization  632 non-null    object
#  4   Definition      865 non-null    object
#  5   Notes           557 non-null    object
#  6   Display Name    873 non-null    object
#  7   Section         873 non-null    object
# dtypes: object(8)
# memory usage: 54.7+ KB

# %%
tax_deets.columns = [x.lower() for x in tax_deets.columns]
tax_deets = tax_deets.rename(columns = {'code' : 'taxonomy_code'})
tax_deets
# Out:
#     taxonomy_code                             grouping  \
# 0      193200000X                                Group
# 1      193400000X                                Group
# 2      207K00000X  Allopathic & Osteopathic Physicians
# 3      207KA0200X  Allopathic & Osteopathic Physicians
# 4      207KI0005X  Allopathic & Osteopathic Physicians
# ..            ...                                  ...
# 868    343800000X              Transportation Services
# 869    344600000X              Transportation Services
# 870    347D00000X              Transportation Services
# 871    347E00000X              Transportation Services
# 872    342000000X              Transportation Services
#
#                       classification                    specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# 3               Allergy & Immunology                           Allergy
# 4               Allergy & Immunology  Clinical & Laboratory Immunology
# ..                               ...                               ...
# 868  Secured Medical Transport (VAN)                               NaN
# 869                             Taxi                               NaN
# 870                            Train                               NaN
# 871            Transportation Broker                               NaN
# 872   Transportation Network Company                               NaN
#
#                                             definition  \
# 0    A business group of one or more individual pra...
# 1    A business group of one or more individual pra...
# 2    An allergist-immunologist is trained in evalua...
# 3    A physician who specializes in the diagnosis, ...
# 4    An allergy and immunology physician who specia...
# ..                                                 ...
# 868  A public or privately owned transportation ser...
# 869  A land commercial vehicle used for the transpo...
# 870  An organization or business licensed to provid...
# 871  An organization that provides transportation f...
# 872  A ride-sharing company that provides prearrang...
#
#                                                  notes  \
# 0                                      [7/1/2003: new]
# 1                                      [7/1/2003: new]
# 2    Source: American Board of Medical Specialties,...
# 3             Source: National Uniform Claim Committee
# 4    Source: National Uniform Claim Committee, 2022...
# ..                                                 ...
# 868                                                NaN
# 869                                                NaN
# 870                                                NaN
# 871  Source: Section 6083 of the Deficit Reduction ...
# 872  Source:  National Uniform Claim Committee, www...
#
#                                           display name         section
# 0                                Multi-Specialty Group      Individual
# 1                               Single Specialty Group      Individual
# 2                       Allergy & Immunology Physician      Individual
# 3                                    Allergy Physician      Individual
# 4    Clinical & Laboratory Immunology (Allergy & Im...      Individual
# ..                                                 ...             ...
# 868                    Secured Medical Transport (VAN)  Non-Individual
# 869                                               Taxi  Non-Individual
# 870                                              Train  Non-Individual
# 871                              Transportation Broker  Non-Individual
# 872                     Transportation Network Company  Non-Individual
#
# [873 rows x 8 columns]

# %% [markdown]
# # create the taxonomy table and add it to the database
# tax_deets.to_sql('taxonomy', db, if_exists = 'append', index = False)

# %% [markdown]
# ## Zip Code/CBSA Date

# %%
zip_cbsa = pd.read_excel('../data/ZIP_CBSA_122021.xlsx')

# %%
zip_cbsa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47484 entries, 0 to 47483
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   zip                  47484 non-null  int64
#  1   cbsa                 47484 non-null  int64
#  2   usps_zip_pref_city   47484 non-null  object
#  3   usps_zip_pref_state  47484 non-null  object
#  4   res_ratio            47484 non-null  float64
#  5   bus_ratio            47484 non-null  float64
#  6   oth_ratio            47484 non-null  float64
#  7   tot_ratio            47484 non-null  float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 2.9+ MB

# %%
zip_cbsa = zip_cbsa.rename(columns = {'usps_zip_pref_city' : 'city',
                              'usps_zip_pref_state' : 'state'})
zip_cbsa['zip'] = zip_cbsa['zip'].astype(str).str.zfill(5)

# %%
zip_cbsa
# Out:
#          zip   cbsa         city state  res_ratio  bus_ratio  oth_ratio  \
# 0      00683  41900   SAN GERMAN    PR   0.999842        1.0        1.0
# 1      00683  32420   SAN GERMAN    PR   0.000158        0.0        0.0
# 2      00923  41980     SAN JUAN    PR   1.000000        1.0        1.0
# 3      01010  44140    BRIMFIELD    MA   0.976896        1.0        1.0
# 4      01010  49340    BRIMFIELD    MA   0.023104        0.0        0.0
# ...      ...    ...          ...   ...        ...        ...        ...
# 47479  60684  16980      CHICAGO    IL   0.000000        1.0        0.0
# 47480  33945  15980     PINELAND    FL   0.000000        0.0        1.0
# 47481  78144  99999  PANNA MARIA    TX   0.000000        1.0        0.0
# 47482  12257  10580       ALBANY    NY   0.000000        1.0        0.0
# 47483  42061  32460        LOWES    KY   0.000000        0.0        1.0
#
#        tot_ratio
# 0       0.999855
# 1       0.000145
# 2       1.000000
# 3       0.977816
# 4       0.022184
# ...          ...
# 47479   1.000000
# 47480   1.000000
# 47481   1.000000
# 47482   1.000000
# 47483   1.000000
#
# [47484 rows x 8 columns]

# %% [markdown]
# # create the zip_cbsa table and add it to the database
# zip_cbsa.to_sql('zip_cbsa', db, if_exists = 'append', index = False)

# %% [markdown]
# ## Hop Teaming Data

# %%
hop_sample = pd.read_csv('../data/DocGraph_Hop_Teaming_2018.csv', nrows = 10000)

# %%
hop_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   from_npi           10000 non-null  int64
#  1   to_npi             10000 non-null  int64
#  2   patient_count      10000 non-null  int64
#  3   transaction_count  10000 non-null  int64
#  4   average_day_wait   10000 non-null  float64
#  5   std_day_wait       10000 non-null  float64
# dtypes: float64(2), int64(4)
# memory usage: 468.9 KB

# %%
hop_sample
# Out:
#         from_npi      to_npi  patient_count  transaction_count  \
# 0     1508062167  1730166109            350                370
# 1     1508065640  1730166109             25                 25
# 2     1508052093  1730166109             16                 16
# 3     1508172545  1730166109             14                 14
# 4     1508285131  1730166109             20                 21
# ...          ...         ...            ...                ...
# 9995  1508026980  1730477589             36                 46
# 9996  1497997050  1730477589             38                 43
# 9997  1497977268  1730477761             14                 14
# 9998  1508024217  1730477811             12                 12
# 9999  1508805722  1730477811             26                 26
#
#       average_day_wait  std_day_wait
# 0               53.922        72.612
# 1               49.800        55.006
# 2              109.500        70.593
# 3              103.357        75.483
# 4               89.952        89.880
# ...                ...           ...
# 9995            64.239        77.845
# 9996            40.395        60.289
# 9997            37.857        72.533
# 9998            59.000        46.043
# 9999           117.500        82.087
#
# [10000 rows x 6 columns]

# %% [markdown]
# # create the referrals table and add it to the database
# for chunk in tqdm(pd.read_csv('../data/DocGraph_Hop_Teaming_2018.csv', chunksize = 10000)):
#     chunk.to_sql('referrals', db, if_exists = 'append', index = False)            # append to referrals table
